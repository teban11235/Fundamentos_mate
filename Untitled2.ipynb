# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos extraídos de la tabla
x = np.array([-3.0, -2.0, -1.5, -1.0, -0.5, 0.5, 1.0, 1.5, 2.0, 3.0])
y = np.array([-1/3, -1/2, -2/3, -1, -2, 2, 1, 2/3, 1/2, 1/3])

# Crear la gráfica solo con puntos
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='y = 1/x')

# Configuración del gráfico
plt.axhline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.axvline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.xlabel('x')
plt.ylabel('y = 1/x')
plt.title('Gráfica de la función y = 1/x (solo puntos)')
plt.grid(alpha=0.4)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para la función y = 2x - 1
x = np.array([-3.0, -2.0, -1.5, -1.0, -0.5, 0, 0.5, 1.0, 1.5, 2.0, 3.0])
y = 2 * x - 1

# Crear la gráfica solo con puntos
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='green', label='y = 2x - 1')

# Configuración del gráfico
plt.axhline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.axvline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.xlabel('x')
plt.ylabel('y = 2x - 1')
plt.title('Gráfica de la función y = 2x - 1 (solo puntos)')
plt.grid(alpha=0.4)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para la función y = x^2 - 4
x = np.array([-3.0, -2.0, -1.5, -1.0, -0.5, 0, 0.5, 1.0, 1.5, 2.0, 3.0])
y = x**2 - 4

# Crear la gráfica solo con puntos
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='purple', label='y = x^2 - 4')

# Configuración del gráfico
plt.axhline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.axvline(0, color='black', linewidth=0.8, linestyle='--', alpha=0.6)
plt.xlabel('x')
plt.ylabel('y = x^2 - 4')
plt.title('Gráfica de la función y = x^2 - 4 (solo puntos)')
plt.grid(alpha=0.4)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear datos para la función y = 2x - 4
x = np.linspace(-1, 5, 500)  # Más puntos para una línea suave
y = 2 * x - 4

# Calcular intersecciones con los ejes
# Intersección con el eje X (y = 0): 2x - 4 = 0 => x = 2
interseccion_x = np.array([2])
interseccion_y_x = np.array([0])

# Intersección con el eje Y (x = 0): y = 2(0) - 4 => y = -4
interseccion_y = np.array([0])
interseccion_x_y = np.array([-4])

# Crear la gráfica
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='y = 2x - 4', color='blue')  # Línea continua
plt.scatter(interseccion_x, interseccion_y_x, color='red', label='Intersección con eje X', zorder=5)
plt.scatter(interseccion_y, interseccion_x_y, color='green', label='Intersección con eje Y', zorder=5)

# Configuración del gráfico
plt.axhline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.6)
plt.axvline(0, color='black', linestyle='--', linewidth=0.8, alpha=0.6)
plt.xlabel('x')
plt.ylabel('y = 2x - 4')
plt.title('Gráfica de la función y = 2x - 4 con intersecciones')
plt.grid(alpha=0.4)
plt.legend()
plt.show()
